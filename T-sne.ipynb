# %%
import pandas as pd

# %%
df1 = pd.read_csv("Data/public-annotations.csv")

# %%
df2 = pd.read_csv("Data/public_cohen_dataset_features.csv")

# %%
df = df1.join(df2)

# %%
print(df2.columns)
# Out:
# Index(['original_shape_Elongation', 'original_shape_Flatness',
#        'original_shape_LeastAxisLength', 'original_shape_MajorAxisLength',
#        'original_shape_Maximum2DDiameterColumn',
#        'original_shape_Maximum2DDiameterRow',
#        'original_shape_Maximum2DDiameterSlice',
#        'original_shape_Maximum3DDiameter', 'original_shape_MeshVolume',
#        'original_shape_MinorAxisLength',
#        ...
#        'original_glszm_SmallAreaHighGrayLevelEmphasis',
#        'original_glszm_SmallAreaLowGrayLevelEmphasis',
#        'original_glszm_ZoneEntropy', 'original_glszm_ZonePercentage',
#        'original_glszm_ZoneVariance', 'original_ngtdm_Busyness',
#        'original_ngtdm_Coarseness', 'original_ngtdm_Complexity',
#        'original_ngtdm_Contrast', 'original_ngtdm_Strength'],
#       dtype='object', length=107)

# %%
df = df.drop(['S-A', 'S-B', 'S-C', 'S-D', 'S-E', 'S-F', 'J-A', 'J-B', 'J-C', 'J-D', 'J-E', 'J-F', 'J-Global'], axis = 1)

# %%
df
# Out:
#                                               filename  S-Global  \
# 0            6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg        18
# 1       acute-respiratory-distress-syndrome-ards-1.jpg        18
# 2                                        16654_4_1.jpg        17
# 3                        pneumocystis-pneumonia-12.png        15
# 4                            covid-19-pneumonia-12.jpg        14
# ..                                                 ...       ...
# 187       1-s2.0-S1684118220300682-main.pdf-002-a2.png         0
# 188  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...         0
# 189          1F6343EE-AFEC-4B7D-97F5-62797EE18767.jpeg         0
# 190                        covid-19-pneumonia-35-2.jpg         0
# 191                                     immagine 3.png         0
#
#      original_shape_Elongation  original_shape_Flatness  \
# 0                     0.831360                        0
# 1                     0.634875                        0
# 2                     0.817698                        0
# 3                     0.744292                        0
# 4                     0.844240                        0
# ..                         ...                      ...
# 187                   0.726248                        0
# 188                   0.749846                        0
# 189                   0.709706                        0
# 190                   0.786687                        0
# 191                   0.765737                        0
#
#      original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                                 0                      216.797446
# 1                                 0                      237.779702
# 2                                 0                      250.979861
# 3                                 0                      215.384852
# 4                                 0                      263.813771
# ..                              ...                             ...
# 187                               0                      231.046471
# 188                               0                      279.091272
# 189                               0                      281.856855
# 190                               0                      212.174840
# 191                               0                      237.214762
#
#      original_shape_Maximum2DDiameterColumn  \
# 0                                       195
# 1                                       202
# 2                                       224
# 3                                       181
# 4                                       234
# ..                                      ...
# 187                                     199
# 188                                     242
# 189                                     242
# 190                                     185
# 191                                     191
#
#      original_shape_Maximum2DDiameterRow  \
# 0                                    166
# 1                                    140
# 2                                    199
# 3                                    157
# 4                                    206
# ..                                   ...
# 187                                  171
# 188                                  182
# 189                                  188
# 190                                  173
# 191                                  178
#
#      original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               229.941297                        229.941297
# 1                               223.042597                        223.042597
# 2                               269.742470                        269.742470
# 3                               208.216234                        208.216234
# 4                               280.957292                        280.957292
# ..                                     ...                               ...
# 187                             217.165835                        217.165835
# 188                             287.255983                        287.255983
# 189                             266.056385                        266.056385
# 190                             214.114455                        214.114455
# 191                             249.833945                        249.833945
#
#      ...  original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0    ...                                      14.719810
# 1    ...                                      18.300492
# 2    ...                                      19.502724
# 3    ...                                       6.754840
# 4    ...                                      16.289337
# ..   ...                                            ...
# 187  ...                                      13.842609
# 188  ...                                      10.119319
# 189  ...                                      14.795840
# 190  ...                                      13.415820
# 191  ...                                       3.826451
#
#      original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                        0.023416                    5.380877
# 1                                        0.024657                    4.927192
# 2                                        0.021289                    5.022237
# 3                                        0.067922                    4.509018
# 4                                        0.034828                    5.603516
# ..                                            ...                         ...
# 187                                      0.023212                    5.767996
# 188                                      0.057115                    6.502848
# 189                                      0.094753                    5.116855
# 190                                      0.037035                    5.121973
# 191                                      0.146371                    5.451677
#
#      original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                         0.016533                 147655.60460
# 1                         0.024426                  52897.49643
# 2                         0.013910                 272887.44190
# 3                         0.022156                 104034.14840
# 4                         0.047980                  11284.92068
# ..                             ...                          ...
# 187                       0.011570                 139048.37820
# 188                       0.026678                  12995.22404
# 189                       0.017664                  81817.65785
# 190                       0.011860                 109114.14560
# 191                       0.009876                 162429.23190
#
#      original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                  17.028833                   0.001094
# 1                  17.186833                   0.001120
# 2                  17.353196                   0.000866
# 3                  36.502534                   0.001092
# 4                  28.816868                   0.000581
# ..                       ...                        ...
# 187                10.818241                   0.001918
# 188                35.124314                   0.001025
# 189                25.359959                   0.001384
# 190                 9.671949                   0.002594
# 191                27.782433                   0.001935
#
#      original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                     5.156082                 0.007431
# 1                     6.932874                 0.010335
# 2                     5.949896                 0.004677
# 3                     3.038377                 0.010741
# 4                    15.135244                 0.015336
# ..                         ...                      ...
# 187                   4.318092                 0.015289
# 188                   7.957738                 0.031214
# 189                   4.525446                 0.027329
# 190                   3.646046                 0.012119
# 191                   1.893365                 0.013987
#
#      original_ngtdm_Strength
# 0                   0.032236
# 1                   0.035465
# 2                   0.037499
# 3                   0.015760
# 4                   0.023144
# ..                       ...
# 187                 0.045680
# 188                 0.028119
# 189                 0.029443
# 190                 0.062331
# 191                 0.021928
#
# [192 rows x 109 columns]

# %%
df_nonames = df.drop('filename', axis = 1)

# %%
df_nonames
# Out:
#      S-Global  original_shape_Elongation  original_shape_Flatness  \
# 0          18                   0.831360                        0
# 1          18                   0.634875                        0
# 2          17                   0.817698                        0
# 3          15                   0.744292                        0
# 4          14                   0.844240                        0
# ..        ...                        ...                      ...
# 187         0                   0.726248                        0
# 188         0                   0.749846                        0
# 189         0                   0.709706                        0
# 190         0                   0.786687                        0
# 191         0                   0.765737                        0
#
#      original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                                 0                      216.797446
# 1                                 0                      237.779702
# 2                                 0                      250.979861
# 3                                 0                      215.384852
# 4                                 0                      263.813771
# ..                              ...                             ...
# 187                               0                      231.046471
# 188                               0                      279.091272
# 189                               0                      281.856855
# 190                               0                      212.174840
# 191                               0                      237.214762
#
#      original_shape_Maximum2DDiameterColumn  \
# 0                                       195
# 1                                       202
# 2                                       224
# 3                                       181
# 4                                       234
# ..                                      ...
# 187                                     199
# 188                                     242
# 189                                     242
# 190                                     185
# 191                                     191
#
#      original_shape_Maximum2DDiameterRow  \
# 0                                    166
# 1                                    140
# 2                                    199
# 3                                    157
# 4                                    206
# ..                                   ...
# 187                                  171
# 188                                  182
# 189                                  188
# 190                                  173
# 191                                  178
#
#      original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               229.941297                        229.941297
# 1                               223.042597                        223.042597
# 2                               269.742470                        269.742470
# 3                               208.216234                        208.216234
# 4                               280.957292                        280.957292
# ..                                     ...                               ...
# 187                             217.165835                        217.165835
# 188                             287.255983                        287.255983
# 189                             266.056385                        266.056385
# 190                             214.114455                        214.114455
# 191                             249.833945                        249.833945
#
#      original_shape_MeshVolume  ...  \
# 0                  20389.83333  ...
# 1                  14868.58333  ...
# 2                  24899.83333  ...
# 3                  14152.58333  ...
# 4                  24647.33333  ...
# ..                         ...  ...
# 187                17925.58333  ...
# 188                25977.08333  ...
# 189                24931.08333  ...
# 190                14305.08333  ...
# 191                17648.58333  ...
#
#      original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                        14.719810
# 1                                        18.300492
# 2                                        19.502724
# 3                                         6.754840
# 4                                        16.289337
# ..                                             ...
# 187                                      13.842609
# 188                                      10.119319
# 189                                      14.795840
# 190                                      13.415820
# 191                                       3.826451
#
#      original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                        0.023416                    5.380877
# 1                                        0.024657                    4.927192
# 2                                        0.021289                    5.022237
# 3                                        0.067922                    4.509018
# 4                                        0.034828                    5.603516
# ..                                            ...                         ...
# 187                                      0.023212                    5.767996
# 188                                      0.057115                    6.502848
# 189                                      0.094753                    5.116855
# 190                                      0.037035                    5.121973
# 191                                      0.146371                    5.451677
#
#      original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                         0.016533                 147655.60460
# 1                         0.024426                  52897.49643
# 2                         0.013910                 272887.44190
# 3                         0.022156                 104034.14840
# 4                         0.047980                  11284.92068
# ..                             ...                          ...
# 187                       0.011570                 139048.37820
# 188                       0.026678                  12995.22404
# 189                       0.017664                  81817.65785
# 190                       0.011860                 109114.14560
# 191                       0.009876                 162429.23190
#
#      original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                  17.028833                   0.001094
# 1                  17.186833                   0.001120
# 2                  17.353196                   0.000866
# 3                  36.502534                   0.001092
# 4                  28.816868                   0.000581
# ..                       ...                        ...
# 187                10.818241                   0.001918
# 188                35.124314                   0.001025
# 189                25.359959                   0.001384
# 190                 9.671949                   0.002594
# 191                27.782433                   0.001935
#
#      original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                     5.156082                 0.007431
# 1                     6.932874                 0.010335
# 2                     5.949896                 0.004677
# 3                     3.038377                 0.010741
# 4                    15.135244                 0.015336
# ..                         ...                      ...
# 187                   4.318092                 0.015289
# 188                   7.957738                 0.031214
# 189                   4.525446                 0.027329
# 190                   3.646046                 0.012119
# 191                   1.893365                 0.013987
#
#      original_ngtdm_Strength
# 0                   0.032236
# 1                   0.035465
# 2                   0.037499
# 3                   0.015760
# 4                   0.023144
# ..                       ...
# 187                 0.045680
# 188                 0.028119
# 189                 0.029443
# 190                 0.062331
# 191                 0.021928
#
# [192 rows x 108 columns]

# %% [markdown]
# Coverting to np array for TSNE function

# %%
X = df_nonames.to_numpy()

# %%
from sklearn.manifold import TSNE

# %%
X_embedded = TSNE(n_components=2, learning_rate = 'auto', init = 'random').fit(X)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-36-21dc75a33624> in <module>
# ----> 1 X_embedded = TSNE(n_components=2, learning_rate = 'auto', init = 'random').fit(X)
#
# T:\Users\Luke\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in fit(self, X, y)
#     948         y : Ignored
#     949         """
# --> 950         self.fit_transform(X)
#     951         return self
#
# T:\Users\Luke\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in fit_transform(self, X, y)
#     930             Embedding of the training data in low-dimensional space.
#     931         """
# --> 932         embedding = self._fit(X)
#     933         self.embedding_ = embedding
#     934         return self.embedding_
#
# T:\Users\Luke\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in _fit(self, X, skip_num_points)
#     839         degrees_of_freedom = max(self.n_components - 1, 1)
#     840
# --> 841         return self._tsne(P, degrees_of_freedom, n_samples,
#     842                           X_embedded=X_embedded,
#     843                           neighbors=neighbors_nn,
#
# T:\Users\Luke\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#     880         # higher learning rate controlled via the early exaggeration parameter
#     881         P *= self.early_exaggeration
# --> 882         params, kl_divergence, it = _gradient_descent(obj_func, params,
#     883                                                       **opt_args)
#     884         if self.verbose:
#
# T:\Users\Luke\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     370         np.clip(gains, min_gain, np.inf, out=gains)
#     371         grad *= gains
# --> 372         update = momentum * update - learning_rate * grad
#     373         p += update
#     374
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
